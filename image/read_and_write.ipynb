# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_path = "data//image//lena_color_512.tif"

image=cv2.imread(image_path)

# %%
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
plt.show()

# %%
output_path="output//lena_output.jpeg"

cv2.imwrite(output_path,image)

# %%
print("Varriable type : ",type(image))
# Out:
# Varriable type :  <class 'numpy.ndarray'>

# %%
print("Image is of size {} X {} pixel and has {} channel".format(image.shape[0],image.shape[1],image.shape[2]))
# Out:
# Image is of size 512 X 512 pixel and has 3 channel

# %%
black_image = np.zeros((512,512,3),np.uint8)

# %%
cv2.imwrite("output//black_image.jpeg",black_image)
plt.imshow(black_image)
plt.show()

# %%
random_image = np.random.randint(255, size=(512,512,3),dtype=np.uint8)

# %%
cv2.imwrite("output//random_int_image.jpeg",random_image)
plt.imshow(random_image)
plt.show()
